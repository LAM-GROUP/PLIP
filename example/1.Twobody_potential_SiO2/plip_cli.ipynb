# %% [markdown]
# # PLIP tutorial for fitting PLIP potential for SiO2

# %% [markdown]
# In this tutorial, we will learn to generate a physical lasso lars machine (PLIP) learning ineratomic potetnial for SiO2. For simplicity, we will generate a two body potetnials using gaussian functions as basis functions. To achieve higher accuracy, the three-body and N-body descriptors should be used. We will use the command line interface of PLIP for this example.

# %% [markdown]
# ## Check python version

# %%
# !python --version
# Out:
# Python 3.8.10

# %% [markdown]
# ## Command line interface

# %%
# !plip_fit --help
# Out:
# usage: PLIP [-h] [--yaml {input.yaml}] [--compile] [--genbin {input.txt}]
#             [--train {1}] [--genpot] [--version]
#
# Physical Lassolars interaction potentials
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --yaml {input.yaml}, -i {input.yaml}
#                         PLIP workflow
#   --compile, -c         Compile C++ modules
#   --genbin {input.txt}, -g {input.txt}
#                         Generate binary files
#   --train {1}, -t {1}   Run the lassolars
#   --genpot, -p          Generate potential for all coefficient files
#   --version, -v         version of the package

# %%
# !plip_fit --version
# Out:
# Namespace(compile=False, genbin=None, genpot=False, train=None, version=True, yaml=None)
# 0.2.0

# %% [markdown]
# ## Compile C++ modules

# %%
# !plip_fit --compile
# Out:
# Namespace(compile=True, genbin=None, genpot=False, train=None, version=False, yaml=None)
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/src/plip
# Compilation of XMAT successful.
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/src/plip
# Compilation of GEN_POT successful.

# %% [markdown]
# ## Generate machine learning finger print

# %%
# !plip_fit -g input.txt
# Out:
# Namespace(compile=False, genbin='input.txt', genpot=False, train=None, version=False, yaml=None)
#
# ===================================================================
# =====================   XMAT   CALCULATIONS   =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
# =====================  Input/210.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/207.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/216.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/221.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/205.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/224.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/215.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/211.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/208.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/218.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/206.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/204.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/213.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/217.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/212.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/202.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/209.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/203.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/226.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/219.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/222.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/225.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/223.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/214.poscar  =====================
# 15.8  0  0
# 0  15.8  0
# 0  0  15.8
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/200.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/201.poscar  =====================
# 16  0  0
# 0  16  0
# 0  0  16
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# =====================  Input/220.poscar  =====================
# 15.6  0  0
# 0  15.6  0
# 0  0  15.6
# Size=4
# Na=128  Nb=256
# Distances and angles DONE
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B is done
# ===================================================================
#
# time_run=41067µs
#
# ===================================================================
# ===================================================================
# ===================================================================

# %% [markdown]
# ## Train PLIP potential

# %%
# !plip_fit --train 1
# Out:
# Namespace(compile=False, genbin=None, genpot=False, train='1', version=False, yaml=None)
# Running LassoLars
# ['1']
# 1
# input files:Refs/200.forces
# Input/200.poscar_f1_*bin
# ['Input/200.poscar_f1_2B.bin']
# (1152, 72) (1152,)
# Input/201.poscar_f1_*bin
# ['Input/201.poscar_f1_2B.bin']
# Input/202.poscar_f1_*bin
# ['Input/202.poscar_f1_2B.bin']
# Input/203.poscar_f1_*bin
# ['Input/203.poscar_f1_2B.bin']
# Input/204.poscar_f1_*bin
# ['Input/204.poscar_f1_2B.bin']
# Input/205.poscar_f1_*bin
# ['Input/205.poscar_f1_2B.bin']
# Input/206.poscar_f1_*bin
# ['Input/206.poscar_f1_2B.bin']
# Input/207.poscar_f1_*bin
# ['Input/207.poscar_f1_2B.bin']
# Input/208.poscar_f1_*bin
# ['Input/208.poscar_f1_2B.bin']
# Input/209.poscar_f1_*bin
# ['Input/209.poscar_f1_2B.bin']
# Input/210.poscar_f1_*bin
# ['Input/210.poscar_f1_2B.bin']
# Input/211.poscar_f1_*bin
# ['Input/211.poscar_f1_2B.bin']
# Input/212.poscar_f1_*bin
# ['Input/212.poscar_f1_2B.bin']
# Input/213.poscar_f1_*bin
# ['Input/213.poscar_f1_2B.bin']
# Input/214.poscar_f1_*bin
# ['Input/214.poscar_f1_2B.bin']
# Input/215.poscar_f1_*bin
# ['Input/215.poscar_f1_2B.bin']
# Input/216.poscar_f1_*bin
# ['Input/216.poscar_f1_2B.bin']
# Input/217.poscar_f1_*bin
# ['Input/217.poscar_f1_2B.bin']
# Input/218.poscar_f1_*bin
# ['Input/218.poscar_f1_2B.bin']
# Input/219.poscar_f1_*bin
# ['Input/219.poscar_f1_2B.bin']
# Input/220.poscar_f1_*bin
# ['Input/220.poscar_f1_2B.bin']
# Input/221.poscar_f1_*bin
# ['Input/221.poscar_f1_2B.bin']
# Input/222.poscar_f1_*bin
# ['Input/222.poscar_f1_2B.bin']
# Input/223.poscar_f1_*bin
# ['Input/223.poscar_f1_2B.bin']
# Input/224.poscar_f1_*bin
# ['Input/224.poscar_f1_2B.bin']
# Input/225.poscar_f1_*bin
# ['Input/225.poscar_f1_2B.bin']
# Input/226.poscar_f1_*bin
# ['Input/226.poscar_f1_2B.bin']
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 1e-07 0.7751220120483292 0.7488432695748984 0.35216316459681946 0.3536563766504264 0.271721579515877 0.2728385587194719 35 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 6e-07 0.7680367752835522 0.7416716353701057 0.35766794812492664 0.3586700637949137 0.2749113087532107 0.2760127278210621 28 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 1e-06 0.7650748249102582 0.7387935177909343 0.3599442448701448 0.3606625574259679 0.27625112610891656 0.2775316309541619 29 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 6e-06 0.753561219894755 0.7275017051959592 0.3686591178991805 0.36837570261528557 0.2802051015520404 0.28229256509270684 27 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 1e-05 0.7447418761833696 0.7199180340440562 0.37519776340126243 0.3734665036025883 0.28353721715359115 0.2853439825342103 26 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 6e-05 0.6048603257904144 0.5791720738113928 0.4668160432083884 0.4577847896195891 0.33680329949062665 0.3325024977752612 17 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 0.0001 0.49672440599250056 0.47134277457281504 0.5268335080612734 0.5130930935119138 0.3751828432147875 0.36567035897718025 14 72 0.5157261638486531
# /home/akammothumk/Documents/Work/CEMES/1.Projects/1.NucleFox/9.PLIP_JOSS/PLIP/env/lib/python3.8/site-packages/sklearn/linear_model/_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# 0.0006 0.14912754649167637 0.14438446370351754 0.6850191087073252 0.6527523043915657 0.4709950423125756 0.45029996235440817 4 72 0.5157261638486531

# %%
# !cat Out_1.log
# Out:
# 1e-07 0.773071 0.786982 0.351714 0.362935 0.271301 0.280738 35 72 0.513752
# 6e-07 0.765859 0.781681 0.357259 0.367424 0.274546 0.28205 29 72 0.513752
# 1e-06 0.762962 0.779706 0.359462 0.369081 0.27589 0.282722 27 72 0.513752
# 6e-06 0.751391 0.769749 0.368131 0.377331 0.279917 0.285288 27 72 0.513752
# 1e-05 0.742328 0.761347 0.374782 0.384153 0.283369 0.287944 26 72 0.513752
# 6e-05 0.600258 0.6186 0.466804 0.485637 0.337083 0.341511 16 72 0.513752
# 0.0001 0.491732 0.505184 0.526369 0.55315 0.375217 0.380894 13 72 0.513752
# 0.0006 0.145631 0.136204 0.682444 0.730848 0.470159 0.487636 2 72 0.513752

# %%
## Comparison of forces Training and Prediction
import matplotlib.pyplot as plt
import numpy as np

yref_train, yplip_train = np.genfromtxt('ResultsTrain6e-06_1.txt',usecols=(1,2),unpack=True)
yref_test, yplip_test = np.genfromtxt('ResultsTest6e-06_1.txt',usecols=(1,2),unpack=True)

plt.scatter(yref_train,yplip_train,label='Train')
plt.scatter(yref_test,yplip_test,c='r',label='Test')
lims = [
    np.min([plt.xlim(), plt.ylim()]),  # min of both axes
    np.max([plt.xlim(), plt.ylim()]),  # max of both axes
]

plt.plot(lims, lims, 'k--', alpha=0.75, zorder=0)
plt.legend()

# %% [markdown]
# ## Generate Potential for LAMMPS

# %%
# !plip_fit --genpot
# Out:
# Namespace(compile=False, genbin=None, genpot=True, train=None, version=False, yaml=None)
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   3.44626  0.5  6
# 2B     0   593.987  1.5  0.5
# 2B     0   -89.8052  1.5  1
# 2B     0   13.614  1.5  2
# 2B     0   -6.87658  1.5  2.5
# 2B     0   5.55183  1.5  3
# 2B     0   -1.06377  1.5  3.5
# 2B     0   1.44715  1.5  4
# 2B     0   0.338764  1.5  4.5
# 2B     0   -0.287027  1.5  5
# 2B     0   -0.948017  1.5  5.5
# 2B     1   -18.8176  0.5  6
# 2B     1   80.5398  1.5  0.5
# 2B     1   -24.8119  1.5  1
# 2B     1   9.77318  1.5  1.5
# 2B     1   -1.0602  1.5  2
# 2B     1   1.38745  1.5  3
# 2B     1   -0.861719  1.5  3.5
# 2B     1   1.93113  1.5  4
# 2B     1   -0.107692  1.5  4.5
# 2B     1   6.21909  1.5  5
# 2B     1   2.65768  1.5  5.5
# 2B     1   14.2059  1.5  6
# 2B     2   49.4813  1.5  0.5
# 2B     2   -35.6105  1.5  1
# 2B     2   14.0165  1.5  1.5
# 2B     2   -8.08311  1.5  2
# 2B     2   2.98449  1.5  2.5
# 2B     2   -3.07068  1.5  3
# 2B     2   1.30276  1.5  3.5
# 2B     2   -2.02624  1.5  4
# 2B     2   1.32013  1.5  4.5
# 2B     2   -1.89593  1.5  5
# 2B     2   1.49992  1.5  5.5
# 2B     2   -1.37589  1.5  6
# i_func=72
# ===================================================================
#
# time_run=16µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   2.4912  0.5  2
# 2B     0   0.121064  0.5  2.5
# 2B     0   4.95304  1.5  1.5
# 2B     0   1.05011  1.5  3.5
# 2B     0   -0.0490793  1.5  4
# 2B     0   0.795542  1.5  4.5
# 2B     0   0.175921  1.5  5
# 2B     0   1.00126  1.5  6
# 2B     1   0.614546  0.5  2.5
# 2B     1   0.0598274  0.5  4
# 2B     1   4.38832  1.5  1
# 2B     1   1.67807  1.5  1.5
# 2B     1   0.0681138  1.5  3
# 2B     1   0.00876746  1.5  4.5
# 2B     1   -0.225458  1.5  5.5
# 2B     1   0.238007  1.5  6
# 2B     2   -0.789218  0.5  3.5
# 2B     2   23.1233  1.5  0.5
# 2B     2   -12.8827  1.5  1
# 2B     2   -0.682694  1.5  1.5
# 2B     2   0.371316  1.5  2
# 2B     2   -1.08707  1.5  2.5
# 2B     2   -0.0873763  1.5  4
# 2B     2   0.112259  1.5  4.5
# 2B     2   -0.224494  1.5  5.5
# 2B     2   0.402511  1.5  6
# i_func=72
# ===================================================================
#
# time_run=17µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   0.987885  0.5  3.5
# 2B     0   0.299742  0.5  4
# 2B     0   236.633  1.5  0.5
# 2B     0   -30.4799  1.5  1
# 2B     0   8.22152  1.5  2
# 2B     0   -3.24411  1.5  2.5
# 2B     0   2.62839  1.5  3
# 2B     0   0.905777  1.5  4.5
# 2B     0   2.2602  1.5  6
# 2B     1   0.0758206  0.5  2.5
# 2B     1   0.0268051  0.5  4.5
# 2B     1   36.9843  1.5  0.5
# 2B     1   -8.17886  1.5  1
# 2B     1   4.98359  1.5  1.5
# 2B     1   0.849421  1.5  3
# 2B     1   -0.179233  1.5  3.5
# 2B     1   0.410215  1.5  4
# 2B     1   0.167823  1.5  6
# 2B     2   -0.264248  0.5  1.5
# 2B     2   -0.481402  0.5  3
# 2B     2   -0.829979  0.5  3.5
# 2B     2   -0.165092  0.5  6
# 2B     2   37.1984  1.5  0.5
# 2B     2   -24.1286  1.5  1
# 2B     2   5.92395  1.5  1.5
# 2B     2   -2.53006  1.5  2
# 2B     2   -0.167981  1.5  3
# 2B     2   -0.171219  1.5  5
# i_func=72
# ===================================================================
#
# time_run=14µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   0.748893  0.5  2.5
# 2B     0   4.37534  1.5  1
# 2B     0   3.27802  1.5  1.5
# 2B     0   0.111912  1.5  3.5
# 2B     0   -0.0530528  1.5  5.5
# 2B     1   -0.0811128  0.5  5
# 2B     1   -0.00166662  0.5  5.5
# 2B     1   4.61013  1.5  1
# 2B     1   0.866158  1.5  1.5
# 2B     2   0.0168668  0.5  6
# 2B     2   5.12128  1.5  0.5
# 2B     2   -5.62123  1.5  1.5
# 2B     2   2.15193  1.5  2
# 2B     2   -0.865484  1.5  2.5
# 2B     2   -0.0558328  1.5  3
# 2B     2   -0.0273475  1.5  4
# 2B     2   0.0947281  1.5  5
# i_func=72
# ===================================================================
#
# time_run=13µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   0.504666  0.5  2
# 2B     0   0.246794  0.5  2.5
# 2B     0   -0.00649157  0.5  6
# 2B     0   8.42205  1.5  1
# 2B     0   1.30705  1.5  1.5
# 2B     0   0.11617  1.5  3.5
# 2B     1   4.35806  1.5  1
# 2B     1   0.752331  1.5  1.5
# 2B     1   -0.0243761  1.5  2.5
# 2B     2   2.85948  1.5  0.5
# 2B     2   -3.91657  1.5  1.5
# 2B     2   0.701538  1.5  2
# 2B     2   -0.358486  1.5  3
# 2B     2   0.0346189  1.5  3.5
# i_func=72
# ===================================================================
#
# time_run=12µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   0.00924386  0.5  6
# 2B     0   53.5746  1.5  0.5
# 2B     0   5.593  1.5  2
# 2B     0   -1.06393  1.5  2.5
# 2B     0   1.76327  1.5  3
# 2B     0   1.30599  1.5  3.5
# 2B     0   -0.0411896  1.5  4
# 2B     0   1.49621  1.5  4.5
# 2B     0   2.39225  1.5  6
# 2B     1   0.346527  0.5  2.5
# 2B     1   -0.0985256  0.5  6
# 2B     1   23.4817  1.5  0.5
# 2B     1   -3.67584  1.5  1
# 2B     1   3.89268  1.5  1.5
# 2B     1   0.592909  1.5  3
# 2B     1   -0.0817011  1.5  3.5
# 2B     1   0.277874  1.5  4
# 2B     1   0.0928647  1.5  4.5
# 2B     1   0.302246  1.5  6
# 2B     2   -4.72729  0.5  1.5
# 2B     2   -0.174787  0.5  4
# 2B     2   -0.508097  0.5  4.5
# 2B     2   34.9422  1.5  0.5
# 2B     2   -19.7195  1.5  1
# 2B     2   5.79457  1.5  1.5
# 2B     2   0.0935291  1.5  3
# 2B     2   -0.442673  1.5  3.5
# 2B     2   -0.0109826  1.5  5
# 2B     2   0.00904712  1.5  5.5
# i_func=72
# ===================================================================
#
# time_run=13µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   0.18788  1.5  1
# 2B     1   2.95236  1.5  1
# 2B     1   -0.000434821  1.5  2.5
# 2B     2   -0.456902  1.5  1.5
# i_func=72
# ===================================================================
#
# time_run=11µs
#
# ===================================================================
# ===================================================================
# ===================================================================
#
# ===================================================================
# =====================         READ XMAT       =====================
# ===================================================================
#
#
# =====================     INITIALIZATION     =====================
# Input_folder=Input
# Rcut=6
# R_AA=2.1
# R_BB=2.3
# R_AB=2.4
#
#
#
# Working with Gaus
# list_a= 0.5  1.5
# list_b= 0.5  1  1.5  2  2.5  3  3.5  4  4.5  5  5.5  6
# 2B     0   2.69524  0.5  2
# 2B     0   0.0317478  0.5  4.5
# 2B     0   4.60913  1.5  1.5
# 2B     0   0.443907  1.5  2
# 2B     0   1.45247  1.5  3.5
# 2B     0   -0.333565  1.5  4
# 2B     0   1.28032  1.5  4.5
# 2B     0   1.74847  1.5  6
# 2B     1   0.530741  0.5  2.5
# 2B     1   0.128424  0.5  4
# 2B     1   13.4617  1.5  0.5
# 2B     1   0.09832  1.5  1
# 2B     1   2.74055  1.5  1.5
# 2B     1   0.229872  1.5  3
# 2B     1   0.0976447  1.5  4.5
# 2B     1   -0.092326  1.5  5
# 2B     1   -0.112762  1.5  5.5
# 2B     1   0.270263  1.5  6
# 2B     2   -0.934924  0.5  3.5
# 2B     2   25.4474  1.5  0.5
# 2B     2   -14.6326  1.5  1
# 2B     2   0.085007  1.5  2
# 2B     2   -1.13056  1.5  2.5
# 2B     2   -0.162596  1.5  4
# 2B     2   0.226865  1.5  4.5
# 2B     2   -0.257946  1.5  5
# 2B     2   0.126947  1.5  6
# i_func=72
# ===================================================================
#
# time_run=15µs
#
# ===================================================================
# ===================================================================
# ===================================================================

# %%
# !ls POTS/*
# Out:
# POTS/GenEAM.py	POTS/input.txt
#
# POTS/Coeff1e-04_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff1e-05_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff1e-06_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff1e-07_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff6e-04_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff6e-05_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff6e-06_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt
#
# POTS/Coeff6e-07_1:
# out2B_0.txt  out2B_1.txt  out2B_2.txt

# %% [markdown]
# ## Clean

# %%
# !rm Coeff* Resul* Out_1.* 
# !rm -r TMP POTS
# Out:
# rm: cannot remove 'Coeff*': No such file or directory
# rm: cannot remove 'Resul*': No such file or directory
# rm: cannot remove 'Out_1.*': No such file or directory
# rm: cannot remove 'TMP': No such file or directory

# %%
# !ls
# Out:
# Input  input.txt  plip_cli.ipynb  Refs
